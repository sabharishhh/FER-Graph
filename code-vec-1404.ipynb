# %%
import os
import cv2
import json
import torch
import random
import numpy as np
from tqdm import tqdm
import torch.nn as nn
import mediapipe as mp
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
emotion_map = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}
label_map = {v: i for i, v in enumerate(emotion_map.values())}

# %%
# Face Mesh Setup
mp_face_mesh = mp.solutions.face_mesh # use Face Mesh module
face_mesh = mp_face_mesh.FaceMesh( # landmark grp indices such as FaceMesh_LIPS, FaceMesh_LEFT_EYE etc can also be used
    static_image_mode=True,  # treat each frame image independently
    max_num_faces=1,
    refine_landmarks=True # better precision, especially for iris, lips, nose tip, etc.
)
# Out:
# I0000 00:00:1750940431.946573   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940431.960432   48862 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)

# %%
# Extract temporal facial landmark deltas from a video source:

def extract_distance_features(video_path, save_dir="cache"):
    os.makedirs(save_dir, exist_ok=True)
    output_path = os.path.join(save_dir, os.path.basename(video_path) + ".pt") # compute entire output path including filename to store the file, eg: "cache/02-01-03-01-01-01-01.mp4.pt"

    if os.path.exists(output_path): # avoid reprocessing if already processed
        return torch.load(output_path)

    cap = cv2.VideoCapture(video_path) # open video file (.mp4)
    if not cap.isOpened():
        print(f"Could not open video: {video_path}")
        return None

    # Load global reference landmarks once
    if not hasattr(extract_distance_features, "ref_landmarks_global"):
        try:
            extract_distance_features.ref_landmarks_global = np.load("ref_landmarks_global.npy")  # shape: (468, 3)
        except:
            print("ref_landmarks_global.npy not found or corrupted.")
            return None

    ref_landmarks = extract_distance_features.ref_landmarks_global # store the reference landmarks, shape(468, 3)
    norm_factor = np.linalg.norm(ref_landmarks) # a normalization factor = L2 norm of the entire reference landmark matrix.

    valid_deltas = [] # per frame facial deltas stored in this list 
    frame_id = 0
    max_frames = 50
    min_frames_required = 10

    with mp_face_mesh.FaceMesh(
        static_image_mode=False, # consider temporal characteristics such landmark coherence, face similarity, etc
        max_num_faces=1,         # at most 1 face would suffice
        refine_landmarks=True,
        min_detection_confidence=0.3, # detected faces with confidence < 0.3, eliminated
        min_tracking_confidence=0.3
    ) as face_mesh:

        while cap.isOpened() and frame_id < max_frames: # read each frame   
            success, frame = cap.read()
            if not success:
                break

            brightness = np.mean(frame)
            frame_id += 1

            rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) # convert to RGB Space
            resized = cv2.resize(rgb, (640, 480))        # resize to 640 x 480 pixels for uniformity
 
            result = face_mesh.process(resized) # pass the frame to FaceMesh model
            if result.multi_face_landmarks:
                landmarks = np.array([[lm.x, lm.y, lm.z] for lm in result.multi_face_landmarks[0].landmark]) # extract x, y, z coordinates of each of the 468 points
                if landmarks.shape[0] >= 468:                                                                # ensure at least 468 landmarks are recorded
                    delta = (landmarks[:468] - ref_landmarks) / norm_factor                                  # compute delta between current landmark and global reference
                    if np.isnan(delta).any():                                                                # if NaN values recorded, skip the frame
                        continue
                    valid_deltas.append(delta) # append to list
                else:
                    print(f"rame {frame_id}: invalid landmark count = {landmarks.shape[0]}")
            else:
                print(f"Frame {frame_id}: brightness {brightness:.2f} | No face detected")

    cap.release()

    if len(valid_deltas) >= min_frames_required: # save deltas for the video iff obtained for enough frames
        final = torch.tensor(np.stack(valid_deltas), dtype=torch.float32)
        torch.save(final, output_path)
        return final
    else:
        print(f"No landmarks extracted from any frame: {video_path}")
        return None

# %%
# Filename Parsing Helpers
def get_emotion_label(filename):
    code = filename.split('-')[2]
    return label_map.get(emotion_map.get(code, 'neutral'), 0)

# %%
# Build custom dataset from RAVDESS
class RAVDESSDataset(Dataset):
    def __init__(self, samples, max_frames=32):
        self.samples = samples # samples: a list of video_path and corresponding label tuples, eg: (video_path, label)
        self.max_frames = max_frames

    def __len__(self):
        return len(self.samples) # return number of examples in the dataset

    def __getitem__(self, idx):
        path, label = self.samples[idx] # fetch the path and corresponding label at position indicated by idx
        dist_seq = extract_distance_features(path) # extract delta seq form of tensors of shape (T, 468, 3)
        
        if dist_seq is None:
            return None
        
        return dist_seq.view(dist_seq.shape[0], -1), label
#                             no of frames,   flatten from 468, 3 to 1404

# %%
# Define Model

"""
Input: seq of frame tensors of shape (T, 1404)
Output: emotion label, after prediction (B, 8)
"""

class DistanceLSTM(nn.Module): # create a pyTorch NN
    def __init__(self, input_size=1404, hidden_size=64, num_classes=8): # 64 hidden units per layer, 8 emotion categories
        super().__init__()
        self.conv1 = nn.Conv1d(in_channels=input_size, out_channels=128, kernel_size=3, padding=1) # consider three frames (n-1, n, n+1) over the time axis and apply convolution, reduces memory load and smoothening of noise can be achieved without compressing imp data
        self.lstm = nn.LSTM(input_size=128, hidden_size=64, num_layers=2, batch_first=True)
        self.dropout = nn.Dropout(0.3)  # Dropout added to prevent overfitting
        self.fc = nn.Linear(64, num_classes) # 64 dim to 8 dim

    def forward(self, x):
        x = x.transpose(1, 2)         # (B, T, 1404) → (B, 128 T), to apply convolution over time axis for all 1404 features instead of features axis
        x = self.conv1(x)             # (B, F, T) → (B, 128, T), 1404 compresses to 128
        x = x.transpose(1, 2)         # (B, 128, T) → (B, T, 128), revert it back
        out, _ = self.lstm(x)         # (B, T, 128) → (B, T, 64)
        out = self.dropout(out[:, -1, :])
        return self.fc(out)           # (B, 64) → (B, num_classes)

# %%
def collate_skip_none(batch):
    batch = [b for b in batch if b is not None] # remove none
    if not batch:
        return None # if no face is detected
    return torch.utils.data.dataloader.default_collate(batch)

def train(model, dataloader, optimizer, criterion, device):
    model.train() # model is switched to training mode
    
    total_loss = 0 # initialized to accumulate loss across batches
    
    for batch in dataloader:
        if batch is None: # skip if none
            continue
        
        X, y = batch # X shape = (B, T, 1404), y shape = (B,)
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad() # clr old gradients
        out = model(X)
        loss = criterion(out, y) # cross entropy is used
        loss.backward() # compute grad using backward propogation
        optimizer.step() # update weights using computed grad
        total_loss += loss.item()
        
    return total_loss / len(dataloader) # avg loss per batch

def evaluate(model, dataloader, device):
    model.eval() # put the model to eval mode, disables dropout and batchnorm updates
    correct = total = 0 # initialize coutners
    
    with torch.no_grad(): # disable grad tracking
        for batch in dataloader:
            if batch is None:
                continue
            
            X, y = batch
            X, y = X.to(device), y.to(device)
            
            out = model(X) # forward pass
            pred = torch.argmax(out, dim=1) # class index with highest score
            
            correct += (pred == y).sum().item()
            total += y.size(0)
            
    return correct / total if total > 0 else 0.0 # return accuracy

# %%
# plot confusion matirx:

def plot_confusion_matrix(model, dataloader, device, label_map):
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for X, y in dataloader:
            X = X.to(device)
            output = model(X)
            pred = torch.argmax(output, dim=1).cpu().numpy()
            y_pred.extend(pred)
            y_true.extend(y.numpy())

    cm = confusion_matrix(y_true, y_pred)
    labels = list(label_map.keys())
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap='Blues', xticks_rotation=45)
    plt.title("Confusion Matrix")
    plt.show()

# %%
def run_training_pipeline():
    root = "/home/sabharishhh/Code/ML/dataset/"
    emotion_folders = sorted(os.listdir(root)) # emotion class names
    
    global label_map     # create label map
    label_map = {emotion: idx for idx, emotion in enumerate(emotion_folders)}

    train_list = []
    test_list = []

    for emotion in emotion_folders:
        folder = os.path.join(root, emotion)
        videos = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(".mp4")]
        random.shuffle(videos) # ensures different actors go into train/test operation

        split_idx = int(0.8 * len(videos))  # for 80-20 split
        train_videos = videos[:split_idx]
        test_videos = videos[split_idx:]

        train_list.extend([(v, label_map[emotion]) for v in train_videos]) # a list of tuples, ie., [(video_path_1, label_1), (video_path_2, label_2), ....]
        test_list.extend([(v, label_map[emotion]) for v in test_videos])

    # Dataset and DataLoader setup
    train_set = RAVDESSDataset(train_list) # returns (T, 1404) vectors
    test_set = RAVDESSDataset(test_list)
    
    train_loader = DataLoader(train_set, batch_size=16, shuffle=True, collate_fn=collate_skip_none)
    test_loader = DataLoader(test_set, batch_size=16, shuffle=False, collate_fn=collate_skip_none)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = DistanceLSTM(input_size=1404, hidden_size=64, num_classes=len(label_map)).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) # learning rate = 0.001

    # Weighted Loss
    y_train_labels = [label for _, label in train_list]
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train_labels), y=y_train_labels)
    weight_tensor = torch.tensor(class_weights, dtype=torch.float).to(device)
    criterion = torch.nn.CrossEntropyLoss(weight=weight_tensor)

    # Training loop
    best_test_acc = 0.0
    for epoch in range(1, 101):
        loss = train(model, train_loader, optimizer, criterion, device)
        train_acc = evaluate(model, train_loader, device)
        test_acc = evaluate(model, test_loader, device)
        print(f"Epoch {epoch:02d} | Loss: {loss:.4f} | Train Acc: {train_acc:.2%} | Test Acc: {test_acc:.2%}")

        if test_acc > best_test_acc:
            best_test_acc = test_acc
            torch.save(model.state_dict(), "best_model.pt")
        
        if test_acc >= 0.93:
            print(f"Early stopping: Test accuracy reached {test_acc:.2%} at epoch {epoch}.")
            break
        
    # Save final model
    save_path = "/home/sabharishhh/Code/ML/Model"
    os.makedirs(save_path, exist_ok=True)
    torch.save(model.state_dict(), os.path.join(save_path, "emotion_lstm_model.pth"))
    with open(os.path.join(save_path, "emotion_lstm_labels.json"), "w") as f:
        json.dump(label_map, f)

    plot_confusion_matrix(model, test_loader, device, label_map)

# %%
# Root folder for sorted dataset
root = "/home/sabharishhh/Code/ML/dataset/"
emotion_folders = sorted(os.listdir(root))

# Create label map
label_map = {emotion: idx for idx, emotion in enumerate(emotion_folders)}

# Prepare train/test split
train_list = []
test_list = []

for emotion in emotion_folders:
    folder_path = os.path.join(root, emotion)
    video_files = [f for f in os.listdir(folder_path) if f.endswith(".mp4")]
    video_paths = [os.path.join(folder_path, f) for f in video_files]
    random.shuffle(video_paths)

    split_idx = int(0.8 * len(video_paths))
    train_list += [(p, label_map[emotion]) for p in video_paths[:split_idx]]
    test_list += [(p, label_map[emotion]) for p in video_paths[split_idx:]]

# Cache directory
os.makedirs("cache", exist_ok=True)
cached = set(os.path.basename(f) for f in os.listdir("cache"))

# Filter files that are not yet cached
remaining = [(p, l) for (p, l) in train_list + test_list if os.path.basename(p) + ".pt" not in cached]

print(f"⏳ Resuming — {len(remaining)} videos left to cache")

for path, _ in tqdm(remaining):
    _ = extract_distance_features(path)
# Out:
# ⏳ Resuming — 360 videos left to cache
#   0%|          | 0/360 [00:00<?, ?it/s]I0000 00:00:1750940446.823686   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940446.825851   49284 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   0%|          | 1/360 [00:01<06:56,  1.16s/it]I0000 00:00:1750940447.899847   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940447.901968   49326 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   1%|          | 2/360 [00:01<05:11,  1.15it/s]I0000 00:00:1750940448.571558   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940448.573459   49375 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   1%|          | 3/360 [00:02<04:28,  1.33it/s]I0000 00:00:1750940449.185775   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940449.187906   49469 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   1%|          | 4/360 [00:03<04:10,  1.42it/s]I0000 00:00:1750940449.802893   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940449.804529   49519 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   1%|▏         | 5/360 [00:03<03:50,  1.54it/s]I0000 00:00:1750940450.346081   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940450.347359   49554 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   2%|▏         | 6/360 [00:04<03:21,  1.76it/s]I0000 00:00:1750940450.757748   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940450.758959   49599 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   2%|▏         | 7/360 [00:04<03:01,  1.95it/s]I0000 00:00:1750940451.164137   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940451.165137   49634 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   2%|▏         | 8/360 [00:04<02:47,  2.10it/s]I0000 00:00:1750940451.556235   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940451.557447   49669 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   2%|▎         | 9/360 [00:05<02:38,  2.22it/s]I0000 00:00:1750940451.946335   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940451.947393   49709 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   3%|▎         | 10/360 [00:05<02:30,  2.33it/s]I0000 00:00:1750940452.321980   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940452.323191   49757 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   3%|▎         | 11/360 [00:06<02:27,  2.37it/s]I0000 00:00:1750940452.729639   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940452.730782   49795 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   3%|▎         | 12/360 [00:06<02:21,  2.46it/s]I0000 00:00:1750940453.106987   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940453.108474   49830 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   4%|▎         | 13/360 [00:06<02:21,  2.45it/s]I0000 00:00:1750940453.513461   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940453.515052   49936 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   4%|▍         | 14/360 [00:07<02:18,  2.49it/s]I0000 00:00:1750940453.901606   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940453.902734   49971 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   4%|▍         | 15/360 [00:07<02:20,  2.45it/s]I0000 00:00:1750940454.321575   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940454.322917   50006 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   4%|▍         | 16/360 [00:07<02:18,  2.48it/s]I0000 00:00:1750940454.712676   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940454.713848   50041 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   5%|▍         | 17/360 [00:08<02:17,  2.50it/s]I0000 00:00:1750940455.112712   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940455.114228   50076 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   5%|▌         | 18/360 [00:08<02:15,  2.53it/s]I0000 00:00:1750940455.493362   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940455.494821   50114 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   5%|▌         | 19/360 [00:09<02:12,  2.58it/s]I0000 00:00:1750940455.863327   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940455.864522   50159 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   6%|▌         | 20/360 [00:09<02:09,  2.62it/s]I0000 00:00:1750940456.229979   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940456.230978   50194 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   6%|▌         | 21/360 [00:09<02:10,  2.60it/s]I0000 00:00:1750940456.629901   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940456.631013   50243 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   6%|▌         | 22/360 [00:10<02:10,  2.59it/s]I0000 00:00:1750940457.008235   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940457.009392   50283 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   6%|▋         | 23/360 [00:10<02:11,  2.56it/s]I0000 00:00:1750940457.414265   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940457.415532   50346 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   7%|▋         | 24/360 [00:11<02:11,  2.55it/s]I0000 00:00:1750940457.807332   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940457.808841   50424 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   7%|▋         | 25/360 [00:11<02:11,  2.56it/s]I0000 00:00:1750940458.195993   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940458.197021   50459 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   7%|▋         | 26/360 [00:11<02:10,  2.57it/s]I0000 00:00:1750940458.582681   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940458.584029   50497 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   8%|▊         | 27/360 [00:12<02:09,  2.57it/s]I0000 00:00:1750940458.969797   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940458.970821   50532 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   8%|▊         | 28/360 [00:12<02:05,  2.64it/s]I0000 00:00:1750940459.326038   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940459.326978   50567 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   8%|▊         | 29/360 [00:12<02:05,  2.63it/s]I0000 00:00:1750940459.705529   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940459.706685   50602 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   8%|▊         | 30/360 [00:13<02:03,  2.66it/s]I0000 00:00:1750940460.073424   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940460.079219   50637 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   9%|▊         | 31/360 [00:13<02:05,  2.62it/s]I0000 00:00:1750940460.469747   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940460.470910   50672 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   9%|▉         | 32/360 [00:14<02:05,  2.62it/s]I0000 00:00:1750940460.849484   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940460.850890   50730 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   9%|▉         | 33/360 [00:14<02:06,  2.59it/s]I0000 00:00:1750940461.249024   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940461.250247   50765 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#   9%|▉         | 34/360 [00:14<02:08,  2.53it/s]I0000 00:00:1750940461.665304   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940461.666329   50875 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  10%|▉         | 35/360 [00:15<02:09,  2.50it/s]I0000 00:00:1750940462.074927   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940462.076437   50914 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  10%|█         | 36/360 [00:15<02:09,  2.51it/s]I0000 00:00:1750940462.471782   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940462.472993   50953 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  10%|█         | 37/360 [00:16<02:09,  2.49it/s]I0000 00:00:1750940462.880741   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940462.881878   50988 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  11%|█         | 38/360 [00:16<02:14,  2.40it/s]I0000 00:00:1750940463.330043   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940463.331370   51023 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  11%|█         | 39/360 [00:17<02:11,  2.44it/s]I0000 00:00:1750940463.726434   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940463.727725   51058 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  11%|█         | 40/360 [00:17<02:05,  2.55it/s]I0000 00:00:1750940464.079767   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940464.080802   51093 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  11%|█▏        | 41/360 [00:17<02:01,  2.63it/s]I0000 00:00:1750940464.429001   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940464.434747   51131 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  12%|█▏        | 42/360 [00:18<01:58,  2.68it/s]I0000 00:00:1750940464.784033   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940464.785109   51179 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  12%|█▏        | 43/360 [00:18<01:56,  2.73it/s]I0000 00:00:1750940465.136476   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940465.137766   51214 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  12%|█▏        | 44/360 [00:18<01:53,  2.77it/s]I0000 00:00:1750940465.483332   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940465.488499   51249 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  12%|█▎        | 45/360 [00:19<01:55,  2.74it/s]I0000 00:00:1750940465.861915   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940465.866338   51364 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  13%|█▎        | 46/360 [00:19<01:55,  2.73it/s]I0000 00:00:1750940466.232106   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940466.233406   51415 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  13%|█▎        | 47/360 [00:19<01:55,  2.72it/s]I0000 00:00:1750940466.609746   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940466.610944   51450 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  13%|█▎        | 48/360 [00:20<01:54,  2.73it/s]I0000 00:00:1750940466.961835   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940466.970030   51488 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  14%|█▎        | 49/360 [00:20<01:53,  2.74it/s]I0000 00:00:1750940467.323186   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940467.329138   51523 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  14%|█▍        | 50/360 [00:20<01:52,  2.74it/s]I0000 00:00:1750940467.691282   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940467.692453   51561 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  14%|█▍        | 51/360 [00:21<01:51,  2.76it/s]I0000 00:00:1750940468.044925   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940468.051231   51596 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  14%|█▍        | 52/360 [00:21<01:51,  2.76it/s]I0000 00:00:1750940468.407978   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940468.409051   51631 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  15%|█▍        | 53/360 [00:22<01:53,  2.71it/s]I0000 00:00:1750940468.788782   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940468.789868   51679 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  15%|█▌        | 54/360 [00:22<01:50,  2.77it/s]I0000 00:00:1750940469.133004   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940469.134135   51714 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  15%|█▌        | 55/360 [00:22<01:50,  2.76it/s]I0000 00:00:1750940469.502242   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940469.503553   51749 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  16%|█▌        | 56/360 [00:23<01:50,  2.75it/s]I0000 00:00:1750940469.864501   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940469.865890   51855 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  16%|█▌        | 57/360 [00:23<01:49,  2.77it/s]I0000 00:00:1750940470.222606   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940470.224050   51890 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  16%|█▌        | 58/360 [00:23<01:48,  2.78it/s]I0000 00:00:1750940470.580754   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940470.582170   51928 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  16%|█▋        | 59/360 [00:24<01:47,  2.80it/s]I0000 00:00:1750940470.927082   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940470.928202   51963 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  17%|█▋        | 60/360 [00:24<01:45,  2.83it/s]I0000 00:00:1750940471.277401   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940471.278943   51998 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  17%|█▋        | 61/360 [00:24<01:45,  2.82it/s]I0000 00:00:1750940471.630223   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940471.631533   52033 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  17%|█▋        | 62/360 [00:25<01:46,  2.81it/s]I0000 00:00:1750940471.990781   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940471.991963   52068 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  18%|█▊        | 63/360 [00:25<01:45,  2.82it/s]I0000 00:00:1750940472.340754   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940472.341888   52103 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  18%|█▊        | 64/360 [00:25<01:43,  2.86it/s]I0000 00:00:1750940472.679397   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940472.685324   52138 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  18%|█▊        | 65/360 [00:26<01:43,  2.85it/s]I0000 00:00:1750940473.035123   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940473.036264   52186 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  18%|█▊        | 66/360 [00:26<01:41,  2.89it/s]I0000 00:00:1750940473.363342   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940473.364514   52221 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  19%|█▊        | 67/360 [00:27<01:43,  2.84it/s]I0000 00:00:1750940473.740699   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940473.741694   52263 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  19%|█▉        | 68/360 [00:27<01:42,  2.84it/s]I0000 00:00:1750940474.080622   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940474.081924   52369 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  19%|█▉        | 69/360 [00:27<01:41,  2.87it/s]I0000 00:00:1750940474.428169   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940474.434918   52404 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  19%|█▉        | 70/360 [00:28<01:40,  2.88it/s]I0000 00:00:1750940474.774090   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940474.775182   52439 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  20%|█▉        | 71/360 [00:28<01:40,  2.87it/s]I0000 00:00:1750940475.119086   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940475.120292   52474 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  20%|██        | 72/360 [00:28<01:41,  2.84it/s]I0000 00:00:1750940475.479501   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940475.480601   52509 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  20%|██        | 73/360 [00:29<01:41,  2.83it/s]I0000 00:00:1750940475.840876   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940475.842302   52544 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  21%|██        | 74/360 [00:29<01:44,  2.74it/s]I0000 00:00:1750940476.235071   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940476.243490   52579 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  21%|██        | 75/360 [00:29<01:46,  2.68it/s]I0000 00:00:1750940476.626155   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940476.627923   52617 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  21%|██        | 76/360 [00:30<01:47,  2.64it/s]I0000 00:00:1750940477.010938   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940477.011935   52665 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  21%|██▏       | 77/360 [00:30<01:47,  2.64it/s]I0000 00:00:1750940477.389452   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940477.399112   52700 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  22%|██▏       | 78/360 [00:31<01:44,  2.69it/s]I0000 00:00:1750940477.752258   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940477.753351   52735 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  22%|██▏       | 79/360 [00:31<01:45,  2.66it/s]I0000 00:00:1750940478.135289   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940478.136471   52841 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  22%|██▏       | 80/360 [00:31<01:47,  2.59it/s]I0000 00:00:1750940478.541096   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940478.542216   52876 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  22%|██▎       | 81/360 [00:32<01:46,  2.62it/s]I0000 00:00:1750940478.913880   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940478.915456   52911 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  23%|██▎       | 82/360 [00:32<01:43,  2.68it/s]I0000 00:00:1750940479.267216   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940479.268556   52946 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  23%|██▎       | 83/360 [00:32<01:42,  2.70it/s]I0000 00:00:1750940479.632380   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940479.633642   52984 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  23%|██▎       | 84/360 [00:33<01:40,  2.74it/s]I0000 00:00:1750940479.984950   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940479.991364   53020 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  24%|██▎       | 85/360 [00:33<01:39,  2.76it/s]I0000 00:00:1750940480.346506   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940480.347660   53055 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  24%|██▍       | 86/360 [00:33<01:38,  2.78it/s]I0000 00:00:1750940480.694874   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940480.695999   53090 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  24%|██▍       | 87/360 [00:34<01:36,  2.82it/s]I0000 00:00:1750940481.036644   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940481.037649   53125 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  24%|██▍       | 88/360 [00:34<01:37,  2.78it/s]I0000 00:00:1750940481.404321   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940481.405377   53173 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  25%|██▍       | 89/360 [00:35<01:36,  2.82it/s]I0000 00:00:1750940481.751565   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940481.757105   53208 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  25%|██▌       | 90/360 [00:35<01:34,  2.86it/s]I0000 00:00:1750940482.089790   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940482.096359   53243 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  25%|██▌       | 91/360 [00:35<01:35,  2.81it/s]I0000 00:00:1750940482.464991   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940482.466393   53352 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  26%|██▌       | 92/360 [00:36<01:35,  2.80it/s]I0000 00:00:1750940482.824508   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940482.825764   53387 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  26%|██▌       | 93/360 [00:36<01:35,  2.80it/s]I0000 00:00:1750940483.185511   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940483.186715   53422 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  26%|██▌       | 94/360 [00:36<01:35,  2.80it/s]I0000 00:00:1750940483.535290   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940483.540876   53457 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  26%|██▋       | 95/360 [00:37<01:35,  2.79it/s]I0000 00:00:1750940483.897433   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940483.898545   53492 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  27%|██▋       | 96/360 [00:37<01:33,  2.81it/s]I0000 00:00:1750940484.246254   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940484.253047   53527 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  27%|██▋       | 97/360 [00:37<01:33,  2.82it/s]I0000 00:00:1750940484.600506   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940484.601764   53563 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  27%|██▋       | 98/360 [00:38<01:32,  2.83it/s]I0000 00:00:1750940484.948218   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940484.949385   53598 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  28%|██▊       | 99/360 [00:38<01:32,  2.83it/s]I0000 00:00:1750940485.304394   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940485.305561   53646 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  28%|██▊       | 100/360 [00:38<01:33,  2.79it/s]I0000 00:00:1750940485.680307   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940485.681901   53685 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  28%|██▊       | 101/360 [00:39<01:33,  2.77it/s]I0000 00:00:1750940486.044825   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940486.045800   53720 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  28%|██▊       | 102/360 [00:39<01:32,  2.80it/s]I0000 00:00:1750940486.391624   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940486.393082   53826 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  29%|██▊       | 103/360 [00:40<01:31,  2.80it/s]I0000 00:00:1750940486.751115   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940486.752851   53861 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  29%|██▉       | 104/360 [00:40<01:31,  2.80it/s]I0000 00:00:1750940487.108308   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940487.110737   53897 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  29%|██▉       | 105/360 [00:40<01:31,  2.79it/s]I0000 00:00:1750940487.464958   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940487.467201   53932 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  29%|██▉       | 106/360 [00:41<01:32,  2.75it/s]I0000 00:00:1750940487.842441   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940487.844151   53967 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  30%|██▉       | 107/360 [00:41<01:31,  2.76it/s]I0000 00:00:1750940488.199932   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940488.200969   54002 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  30%|███       | 108/360 [00:41<01:30,  2.79it/s]I0000 00:00:1750940488.546974   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940488.548382   54040 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  30%|███       | 109/360 [00:42<01:29,  2.79it/s]I0000 00:00:1750940488.909450   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940488.910897   54076 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  31%|███       | 110/360 [00:42<01:30,  2.77it/s]I0000 00:00:1750940489.274368   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940489.280561   54111 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  31%|███       | 111/360 [00:42<01:30,  2.76it/s]I0000 00:00:1750940489.636174   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940489.637285   54159 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  31%|███       | 112/360 [00:43<01:27,  2.83it/s]I0000 00:00:1750940489.974791   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940489.975832   54194 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  31%|███▏      | 113/360 [00:43<01:28,  2.80it/s]I0000 00:00:1750940490.341067   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940490.342983   54243 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  32%|███▏      | 114/360 [00:43<01:27,  2.80it/s]I0000 00:00:1750940490.698849   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940490.699984   54335 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  32%|███▏      | 115/360 [00:44<01:28,  2.77it/s]I0000 00:00:1750940491.063342   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940491.064538   54370 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  32%|███▏      | 116/360 [00:44<01:26,  2.81it/s]I0000 00:00:1750940491.407599   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940491.413093   54406 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  32%|███▎      | 117/360 [00:45<01:27,  2.79it/s]I0000 00:00:1750940491.772584   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940491.773625   54443 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  33%|███▎      | 118/360 [00:45<01:26,  2.80it/s]I0000 00:00:1750940492.127264   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940492.128348   54481 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  33%|███▎      | 119/360 [00:45<01:25,  2.81it/s]I0000 00:00:1750940492.481154   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940492.482407   54516 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  33%|███▎      | 120/360 [00:46<01:24,  2.84it/s]I0000 00:00:1750940492.825351   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940492.826526   54551 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  34%|███▎      | 121/360 [00:46<01:25,  2.81it/s]I0000 00:00:1750940493.196911   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940493.198021   54587 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  34%|███▍      | 122/360 [00:46<01:25,  2.80it/s]I0000 00:00:1750940493.549937   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940493.551527   54635 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  34%|███▍      | 123/360 [00:47<01:26,  2.74it/s]I0000 00:00:1750940493.927228   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940493.928200   54670 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  34%|███▍      | 124/360 [00:47<01:24,  2.80it/s]I0000 00:00:1750940494.275047   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940494.276148   54705 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  35%|███▍      | 125/360 [00:47<01:23,  2.80it/s]I0000 00:00:1750940494.625818   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940494.626808   54815 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  35%|███▌      | 126/360 [00:48<01:23,  2.81it/s]I0000 00:00:1750940494.986598   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940494.988261   54850 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  35%|███▌      | 127/360 [00:48<01:23,  2.79it/s]I0000 00:00:1750940495.342008   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940495.342993   54885 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  36%|███▌      | 128/360 [00:48<01:22,  2.81it/s]I0000 00:00:1750940495.694992   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940495.695985   54921 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  36%|███▌      | 129/360 [00:49<01:23,  2.76it/s]I0000 00:00:1750940496.073241   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940496.074225   54965 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  36%|███▌      | 130/360 [00:49<01:23,  2.76it/s]I0000 00:00:1750940496.436188   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940496.437517   55000 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  36%|███▋      | 131/360 [00:50<01:22,  2.77it/s]I0000 00:00:1750940496.790829   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940496.797368   55035 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  37%|███▋      | 132/360 [00:50<01:21,  2.79it/s]I0000 00:00:1750940497.147408   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940497.149103   55070 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  37%|███▋      | 133/360 [00:50<01:21,  2.78it/s]I0000 00:00:1750940497.513732   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940497.515165   55109 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  37%|███▋      | 134/360 [00:51<01:21,  2.76it/s]I0000 00:00:1750940497.881388   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940497.882823   55157 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  38%|███▊      | 135/360 [00:51<01:22,  2.73it/s]I0000 00:00:1750940498.255082   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940498.256065   55192 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  38%|███▊      | 136/360 [00:51<01:21,  2.74it/s]I0000 00:00:1750940498.621732   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940498.635127   55298 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  38%|███▊      | 137/360 [00:52<01:22,  2.71it/s]I0000 00:00:1750940498.995205   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940498.996384   55334 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  38%|███▊      | 138/360 [00:52<01:20,  2.75it/s]I0000 00:00:1750940499.344127   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940499.345293   55369 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  39%|███▊      | 139/360 [00:53<01:22,  2.69it/s]I0000 00:00:1750940499.736045   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940499.737258   55404 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  39%|███▉      | 140/360 [00:53<01:19,  2.77it/s]I0000 00:00:1750940500.069327   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940500.070514   55439 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  39%|███▉      | 141/360 [00:53<01:18,  2.78it/s]I0000 00:00:1750940500.430634   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940500.432209   55477 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  39%|███▉      | 142/360 [00:54<01:18,  2.78it/s]I0000 00:00:1750940500.794000   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940500.795528   55512 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  40%|███▉      | 143/360 [00:54<01:18,  2.75it/s]I0000 00:00:1750940501.161535   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940501.163162   55547 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  40%|████      | 144/360 [00:54<01:18,  2.75it/s]I0000 00:00:1750940501.524711   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940501.525907   55583 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  40%|████      | 145/360 [00:55<01:18,  2.75it/s]I0000 00:00:1750940501.886415   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940501.887613   55631 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  41%|████      | 146/360 [00:55<01:17,  2.77it/s]I0000 00:00:1750940502.239950   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940502.241261   55672 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  41%|████      | 147/360 [00:55<01:18,  2.72it/s]I0000 00:00:1750940502.625594   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940502.627487   55707 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
# ...
#  86%|████████▋ | 311/360 [01:54<00:17,  2.88it/s]I0000 00:00:1750940561.152303   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940561.153509   62839 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  87%|████████▋ | 312/360 [01:54<00:16,  2.86it/s]I0000 00:00:1750940561.507008   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940561.508466   62874 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  87%|████████▋ | 313/360 [01:55<00:16,  2.87it/s]I0000 00:00:1750940561.851972   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940561.853660   62909 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  87%|████████▋ | 314/360 [01:55<00:15,  2.88it/s]I0000 00:00:1750940562.199866   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940562.201481   62944 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  88%|████████▊ | 315/360 [01:55<00:16,  2.79it/s]I0000 00:00:1750940562.577447   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940562.578823   62979 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  88%|████████▊ | 316/360 [01:56<00:15,  2.84it/s]I0000 00:00:1750940562.921897   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940562.923136   63014 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  88%|████████▊ | 317/360 [01:56<00:15,  2.85it/s]I0000 00:00:1750940563.263753   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940563.265134   63049 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  88%|████████▊ | 318/360 [01:56<00:14,  2.88it/s]I0000 00:00:1750940563.600779   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940563.601861   63101 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  89%|████████▊ | 319/360 [01:57<00:14,  2.88it/s]I0000 00:00:1750940563.952178   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940563.953201   63136 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  89%|████████▉ | 320/360 [01:57<00:13,  2.88it/s]I0000 00:00:1750940564.296417   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940564.297684   63171 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  89%|████████▉ | 321/360 [01:57<00:13,  2.90it/s]I0000 00:00:1750940564.637773   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940564.643814   63277 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  89%|████████▉ | 322/360 [01:58<00:13,  2.90it/s]I0000 00:00:1750940564.985486   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940564.986580   63312 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  90%|████████▉ | 323/360 [01:58<00:12,  2.88it/s]I0000 00:00:1750940565.338958   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940565.340385   63347 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  90%|█████████ | 324/360 [01:58<00:12,  2.85it/s]I0000 00:00:1750940565.694151   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940565.695702   63382 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  90%|█████████ | 325/360 [01:59<00:12,  2.85it/s]I0000 00:00:1750940566.047997   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940566.049256   63417 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  91%|█████████ | 326/360 [01:59<00:11,  2.84it/s]I0000 00:00:1750940566.398161   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940566.399246   63452 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  91%|█████████ | 327/360 [02:00<00:11,  2.84it/s]I0000 00:00:1750940566.751498   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940566.752483   63490 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  91%|█████████ | 328/360 [02:00<00:11,  2.85it/s]I0000 00:00:1750940567.105623   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940567.106979   63525 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  91%|█████████▏| 329/360 [02:00<00:10,  2.85it/s]I0000 00:00:1750940567.455032   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940567.461219   63560 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  92%|█████████▏| 330/360 [02:01<00:10,  2.86it/s]I0000 00:00:1750940567.796751   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940567.797921   63608 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  92%|█████████▏| 331/360 [02:01<00:10,  2.88it/s]I0000 00:00:1750940568.138545   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940568.139791   63643 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  92%|█████████▏| 332/360 [02:01<00:09,  2.89it/s]I0000 00:00:1750940568.487642   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940568.494590   63680 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  92%|█████████▎| 333/360 [02:02<00:09,  2.84it/s]I0000 00:00:1750940568.850195   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940568.851928   63784 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  93%|█████████▎| 334/360 [02:02<00:09,  2.81it/s]I0000 00:00:1750940569.216895   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940569.218192   63819 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  93%|█████████▎| 335/360 [02:02<00:08,  2.81it/s]I0000 00:00:1750940569.567863   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940569.569092   63857 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  93%|█████████▎| 336/360 [02:03<00:08,  2.85it/s]I0000 00:00:1750940569.905760   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940569.906931   63892 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  94%|█████████▎| 337/360 [02:03<00:08,  2.87it/s]I0000 00:00:1750940570.249665   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940570.255308   63927 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  94%|█████████▍| 338/360 [02:03<00:07,  2.89it/s]I0000 00:00:1750940570.594766   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940570.596322   63962 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  94%|█████████▍| 339/360 [02:04<00:07,  2.89it/s]I0000 00:00:1750940570.936745   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940570.937904   63997 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  94%|█████████▍| 340/360 [02:04<00:06,  2.89it/s]I0000 00:00:1750940571.288997   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940571.290085   64032 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  95%|█████████▍| 341/360 [02:04<00:06,  2.87it/s]I0000 00:00:1750940571.639108   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940571.640645   64080 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  95%|█████████▌| 342/360 [02:05<00:06,  2.89it/s]I0000 00:00:1750940571.983793   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940571.986085   64115 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  95%|█████████▌| 343/360 [02:05<00:06,  2.80it/s]I0000 00:00:1750940572.361590   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940572.362796   64150 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  96%|█████████▌| 344/360 [02:05<00:05,  2.82it/s]I0000 00:00:1750940572.713251   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940572.714573   64260 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  96%|█████████▌| 345/360 [02:06<00:05,  2.82it/s]I0000 00:00:1750940573.073939   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940573.075243   64295 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  96%|█████████▌| 346/360 [02:06<00:04,  2.84it/s]I0000 00:00:1750940573.411235   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940573.412718   64330 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  96%|█████████▋| 347/360 [02:07<00:04,  2.86it/s]I0000 00:00:1750940573.754480   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940573.761032   64365 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  97%|█████████▋| 348/360 [02:07<00:04,  2.88it/s]I0000 00:00:1750940574.099321   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940574.105350   64400 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  97%|█████████▋| 349/360 [02:07<00:03,  2.88it/s]I0000 00:00:1750940574.442490   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940574.443791   64435 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  97%|█████████▋| 350/360 [02:08<00:03,  2.90it/s]I0000 00:00:1750940574.782554   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940574.788787   64470 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  98%|█████████▊| 351/360 [02:08<00:03,  2.90it/s]I0000 00:00:1750940575.130600   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940575.131657   64505 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  98%|█████████▊| 352/360 [02:08<00:02,  2.83it/s]I0000 00:00:1750940575.505979   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940575.507416   64544 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  98%|█████████▊| 353/360 [02:09<00:02,  2.82it/s]I0000 00:00:1750940575.859197   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940575.860223   64592 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  98%|█████████▊| 354/360 [02:09<00:02,  2.86it/s]I0000 00:00:1750940576.199511   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940576.200607   64627 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  99%|█████████▊| 355/360 [02:09<00:01,  2.86it/s]I0000 00:00:1750940576.549071   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940576.554810   64662 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  99%|█████████▉| 356/360 [02:10<00:01,  2.85it/s]I0000 00:00:1750940576.900134   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940576.901441   64768 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  99%|█████████▉| 357/360 [02:10<00:01,  2.84it/s]I0000 00:00:1750940577.256759   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940577.257940   64803 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
#  99%|█████████▉| 358/360 [02:10<00:00,  2.84it/s]I0000 00:00:1750940577.611230   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940577.612442   64841 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
# 100%|█████████▉| 359/360 [02:11<00:00,  2.81it/s]I0000 00:00:1750940577.972671   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750940577.974603   64879 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
# 100%|██████████| 360/360 [02:11<00:00,  2.74it/s]

# %%
# Load the face mesh model
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils
mp_style = mp.solutions.drawing_styles

# Input and output paths
video_path = "/home/sabharishhh/Code/ML/dataset/angry/01-01-05-01-01-01-01.mp4"
output_dir = "mesh_frames_output"
os.makedirs(output_dir, exist_ok=True)

# Open video
cap = cv2.VideoCapture(video_path)
frame_idx = 0
saved_count = 0

with mp_face_mesh.FaceMesh(
    static_image_mode=False,
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as face_mesh:

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Convert frame to RGB
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = face_mesh.process(rgb_frame)

        if results.multi_face_landmarks:
            # Draw mesh on the face
            annotated_frame = frame.copy()
            for landmarks in results.multi_face_landmarks:
                custom_spec = mp_drawing.DrawingSpec(color=(33, 222, 255), thickness=1, circle_radius=1)  # Blue lines

                mp_drawing.draw_landmarks(
                    image=annotated_frame,
                    landmark_list=landmarks,
                    connections=mp_face_mesh.FACEMESH_TESSELATION,
                    landmark_drawing_spec=None,
                    connection_drawing_spec=custom_spec,
                )

            # Save every Nth frame (optional)
            if frame_idx % 25 == 0:
                output_path = os.path.join(output_dir, f"mesh_frame_{frame_idx}.png")
                cv2.imwrite(output_path, annotated_frame)
                saved_count += 1

        frame_idx += 1

cap.release()
print(f"✅ Saved {saved_count} mesh frames to {output_dir}")
# Out:
# I0000 00:00:1750939086.324484   15366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1750939086.327036   17196 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.2.8-1ubuntu1~24.04.1), renderer: Mesa Intel(R) UHD Graphics (TGL GT1)
# ✅ Saved 5 mesh frames to mesh_frames_output

# %%
# Step 12: Run Training
run_training_pipeline()
# Out:
# Epoch 01 | Loss: 1.9912 | Train Acc: 21.33% | Test Acc: 19.72%
# Epoch 02 | Loss: 1.9330 | Train Acc: 22.42% | Test Acc: 20.76%
# Epoch 03 | Loss: 1.8937 | Train Acc: 21.20% | Test Acc: 18.69%
# Epoch 04 | Loss: 1.7785 | Train Acc: 32.54% | Test Acc: 29.24%
# Epoch 05 | Loss: 1.7523 | Train Acc: 31.10% | Test Acc: 28.55%
# Epoch 06 | Loss: 1.7092 | Train Acc: 31.28% | Test Acc: 30.80%
# Epoch 07 | Loss: 1.6249 | Train Acc: 39.49% | Test Acc: 34.95%
# Epoch 08 | Loss: 1.5915 | Train Acc: 35.71% | Test Acc: 33.74%
# Epoch 09 | Loss: 1.5474 | Train Acc: 40.83% | Test Acc: 36.16%
# Epoch 10 | Loss: 1.5475 | Train Acc: 43.14% | Test Acc: 39.45%
# Epoch 11 | Loss: 1.4978 | Train Acc: 43.35% | Test Acc: 40.31%
# Epoch 12 | Loss: 1.4312 | Train Acc: 47.96% | Test Acc: 42.91%
# Epoch 13 | Loss: 1.3957 | Train Acc: 49.17% | Test Acc: 43.60%
# Epoch 14 | Loss: 1.4066 | Train Acc: 48.31% | Test Acc: 43.94%
# Epoch 15 | Loss: 1.2788 | Train Acc: 53.34% | Test Acc: 45.33%
# Epoch 16 | Loss: 1.2486 | Train Acc: 54.78% | Test Acc: 47.40%
# Epoch 17 | Loss: 1.1929 | Train Acc: 56.82% | Test Acc: 50.69%
# Epoch 18 | Loss: 1.1875 | Train Acc: 55.95% | Test Acc: 47.23%
# Epoch 19 | Loss: 1.2564 | Train Acc: 59.38% | Test Acc: 50.87%
# Epoch 20 | Loss: 1.1149 | Train Acc: 62.60% | Test Acc: 52.08%
# Epoch 21 | Loss: 1.0125 | Train Acc: 66.46% | Test Acc: 54.50%
# Epoch 22 | Loss: 1.0309 | Train Acc: 65.60% | Test Acc: 52.94%
# Epoch 23 | Loss: 1.0773 | Train Acc: 65.68% | Test Acc: 51.21%
# Epoch 24 | Loss: 0.9501 | Train Acc: 65.16% | Test Acc: 52.94%
# Epoch 25 | Loss: 0.9286 | Train Acc: 66.64% | Test Acc: 56.75%
# Epoch 26 | Loss: 0.8915 | Train Acc: 72.94% | Test Acc: 60.38%
# Epoch 27 | Loss: 0.8620 | Train Acc: 73.07% | Test Acc: 59.69%
# Epoch 28 | Loss: 0.9460 | Train Acc: 65.73% | Test Acc: 56.40%
# Epoch 29 | Loss: 0.8467 | Train Acc: 76.28% | Test Acc: 64.88%
# Epoch 30 | Loss: 0.7108 | Train Acc: 79.45% | Test Acc: 67.30%
# Epoch 31 | Loss: 0.8034 | Train Acc: 76.93% | Test Acc: 64.71%
# Epoch 32 | Loss: 0.6815 | Train Acc: 77.54% | Test Acc: 66.44%
# Epoch 33 | Loss: 0.6448 | Train Acc: 82.71% | Test Acc: 68.69%
# Epoch 34 | Loss: 0.7358 | Train Acc: 81.67% | Test Acc: 67.82%
# Epoch 35 | Loss: 0.5593 | Train Acc: 86.75% | Test Acc: 73.53%
# Epoch 36 | Loss: 0.5324 | Train Acc: 80.54% | Test Acc: 69.38%
# Epoch 37 | Loss: 0.5815 | Train Acc: 84.97% | Test Acc: 71.97%
# Epoch 38 | Loss: 0.4862 | Train Acc: 89.79% | Test Acc: 74.91%
# Epoch 39 | Loss: 0.4411 | Train Acc: 85.45% | Test Acc: 71.45%
# Epoch 40 | Loss: 0.4867 | Train Acc: 85.62% | Test Acc: 74.22%
# Epoch 41 | Loss: 0.4047 | Train Acc: 92.35% | Test Acc: 79.24%
# Epoch 42 | Loss: 0.3739 | Train Acc: 90.27% | Test Acc: 76.30%
# Epoch 43 | Loss: 0.3416 | Train Acc: 92.31% | Test Acc: 81.49%
# Epoch 44 | Loss: 0.4185 | Train Acc: 74.33% | Test Acc: 65.22%
# Epoch 45 | Loss: 0.6036 | Train Acc: 88.58% | Test Acc: 75.95%
# Epoch 46 | Loss: 0.4143 | Train Acc: 89.66% | Test Acc: 76.82%
# Epoch 47 | Loss: 0.3274 | Train Acc: 93.18% | Test Acc: 83.04%
# Epoch 48 | Loss: 0.2530 | Train Acc: 95.44% | Test Acc: 83.22%
# Epoch 49 | Loss: 0.2970 | Train Acc: 93.83% | Test Acc: 82.70%
# Epoch 50 | Loss: 0.4666 | Train Acc: 82.97% | Test Acc: 73.36%
# Epoch 51 | Loss: 0.9557 | Train Acc: 77.11% | Test Acc: 62.63%
# Epoch 52 | Loss: 0.5146 | Train Acc: 92.53% | Test Acc: 81.14%
# Epoch 53 | Loss: 0.2928 | Train Acc: 94.83% | Test Acc: 83.74%
# Epoch 54 | Loss: 0.2574 | Train Acc: 96.13% | Test Acc: 85.81%
# Epoch 55 | Loss: 0.2453 | Train Acc: 95.96% | Test Acc: 86.51%
# Epoch 56 | Loss: 0.2018 | Train Acc: 89.88% | Test Acc: 78.89%
# Epoch 57 | Loss: 0.3141 | Train Acc: 90.44% | Test Acc: 77.34%
# Epoch 58 | Loss: 0.5730 | Train Acc: 85.49% | Test Acc: 72.84%
# Epoch 59 | Loss: 0.3979 | Train Acc: 91.57% | Test Acc: 80.10%
# Epoch 60 | Loss: 0.2652 | Train Acc: 96.57% | Test Acc: 88.41%
# Epoch 61 | Loss: 0.2542 | Train Acc: 89.01% | Test Acc: 80.28%
# Epoch 62 | Loss: 0.2696 | Train Acc: 94.74% | Test Acc: 84.78%
# Epoch 63 | Loss: 0.1543 | Train Acc: 97.87% | Test Acc: 88.41%
# Epoch 64 | Loss: 0.1099 | Train Acc: 98.70% | Test Acc: 90.48%
# Epoch 65 | Loss: 0.2185 | Train Acc: 95.18% | Test Acc: 85.99%
# Epoch 66 | Loss: 0.1584 | Train Acc: 97.83% | Test Acc: 90.83%
# Epoch 67 | Loss: 0.1019 | Train Acc: 98.65% | Test Acc: 92.04%
# Epoch 68 | Loss: 0.1038 | Train Acc: 98.78% | Test Acc: 92.04%
# Epoch 69 | Loss: 0.2668 | Train Acc: 94.79% | Test Acc: 86.33%
# Epoch 70 | Loss: 0.1955 | Train Acc: 94.87% | Test Acc: 86.33%
# Epoch 71 | Loss: 0.2447 | Train Acc: 92.57% | Test Acc: 81.49%
# Epoch 72 | Loss: 0.1331 | Train Acc: 99.09% | Test Acc: 90.31%
# Epoch 73 | Loss: 0.0566 | Train Acc: 99.52% | Test Acc: 92.56%
# Epoch 74 | Loss: 0.1926 | Train Acc: 98.91% | Test Acc: 90.31%
# Epoch 75 | Loss: 0.1351 | Train Acc: 97.18% | Test Acc: 88.93%
# Epoch 76 | Loss: 0.0799 | Train Acc: 98.35% | Test Acc: 88.93%
# Epoch 77 | Loss: 0.0732 | Train Acc: 98.61% | Test Acc: 90.66%
# Epoch 78 | Loss: 0.0678 | Train Acc: 98.44% | Test Acc: 90.83%
# Epoch 79 | Loss: 1.0919 | Train Acc: 74.67% | Test Acc: 66.44%
# Epoch 80 | Loss: 0.4950 | Train Acc: 94.92% | Test Acc: 85.64%
# Epoch 81 | Loss: 0.2184 | Train Acc: 96.87% | Test Acc: 87.54%
# Epoch 82 | Loss: 0.1427 | Train Acc: 98.44% | Test Acc: 89.45%
# Epoch 83 | Loss: 0.0980 | Train Acc: 99.26% | Test Acc: 91.87%
# Epoch 84 | Loss: 0.0763 | Train Acc: 99.39% | Test Acc: 92.39%
# Epoch 85 | Loss: 0.1289 | Train Acc: 97.48% | Test Acc: 90.48%
# Epoch 86 | Loss: 0.0524 | Train Acc: 99.78% | Test Acc: 92.39%
# Epoch 87 | Loss: 0.0531 | Train Acc: 99.26% | Test Acc: 90.48%
# Epoch 88 | Loss: 0.0858 | Train Acc: 99.35% | Test Acc: 91.18%
# Epoch 89 | Loss: 0.0540 | Train Acc: 94.14% | Test Acc: 86.68%
# Epoch 90 | Loss: 0.1631 | Train Acc: 98.09% | Test Acc: 89.97%
# Epoch 91 | Loss: 0.2356 | Train Acc: 96.70% | Test Acc: 89.10%
# Epoch 92 | Loss: 0.2992 | Train Acc: 93.35% | Test Acc: 87.20%
# Epoch 93 | Loss: 0.1942 | Train Acc: 95.92% | Test Acc: 87.72%
# Epoch 94 | Loss: 0.1341 | Train Acc: 98.70% | Test Acc: 91.00%
# Epoch 95 | Loss: 0.0631 | Train Acc: 99.74% | Test Acc: 93.08%
# Early stopping: Test accuracy reached 93.08% at epoch 95.

# %%
def predict_expression(video_path, max_frames=32):
    with open("/home/sabharishhh/Code/ML/Model/emotion_lstm_labels.json") as f:
        label_map = json.load(f)
    inv_map = {v: k for k, v in label_map.items()}
    model = DistanceLSTM(input_size=468, hidden_size=64, num_classes=len(label_map))
    model.load_state_dict(torch.load("/home/sabharishhh/Code/Machine Learning/emotion_lstm_model.pth", map_location=torch.device('cpu')))
    model.eval()
    with torch.no_grad():
        x = extract_distance_features(video_path, max_frames=max_frames, visualize=True)
        if x is None:
            return "No face detected"
        x = x.unsqueeze(0)
        out = model(x)
        pred = torch.argmax(out, dim=1).item()
        return inv_map[pred]

# %%
# Example:
result = predict_expression("/home/sabharishhh/Code/ML/dataset/02-01-06-01-01-01-01.mp4")
print("Predicted Emotion:", result)
